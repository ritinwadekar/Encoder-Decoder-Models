# %%
import pandas as pd
import numpy as np
import torch
from torch import nn
from torch.optim import AdamW
from transformers import RobertaTokenizer, RobertaModel
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import f1_score, precision_score, recall_score
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
import os
import wandb
from huggingface_hub import login as hf_login
from google.colab import userdata

# First, mount Google Drive with explicit output
drive.mount('/content/drive', force_remount=True)
print("Google Drive mounted at /content/drive")

# List files in your Drive root to verify access
print("Files in Google Drive root:")
for file in os.listdir('/content/drive/MyDrive'):
    print(f" - {file}")

# Setup API keys securely using Google Colab secrets
try:
    # Try to get Wandb API key from Colab secrets
    wandb_key = userdata.get(''
    ''
    '')
    if wandb_key:
        print("Found wandb API key in Colab secrets")
        wandb.login(key=wandb_key)
    else:
        # If not in secrets, you might need to login interactively
        print("No wandb API key found in Colab secrets, login interactively")
        wandb.login()

    # Try to get Hugging Face token from Colab secrets
    hf_token = userdata.get('')
    if hf_token:
        print("Found Hugging Face token in Colab secrets")
        hf_login(token=hf_token)
    else:
        print("No Hugging Face token found in Colab secrets")
except Exception as e:
    print(f"Error setting up API keys: {str(e)}")
    print("Continuing without proper authentication...")

# Custom Dataset class with fixed tensor conversion
class EmotionDataset(Dataset):
    def __init__(self, dataframe, tokenizer, max_length=128):
        self.tokenizer = tokenizer
        self.data = dataframe
        self.text = dataframe['Tweet'].values
        self.max_length = max_length
        # Get emotion labels if they exist
        self.emotion_cols = ['anger', 'anticipation', 'disgust', 'fear', 'joy', 'love',
                           'optimism', 'pessimism', 'sadness', 'surprise', 'trust']

        if all(col in dataframe.columns for col in self.emotion_cols):
            # Fix: First convert any string values to NaN, then to float32
            emotion_data = dataframe[self.emotion_cols].replace(['NONE', 'None', 'none'], np.nan)
            emotion_data = emotion_data.apply(pd.to_numeric, errors='coerce')
            self.targets = emotion_data.fillna(0).values.astype(np.float32)
        else:
            self.targets = None

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        text = str(self.text[index])

        # Tokenize the text
        inputs = self.tokenizer.encode_plus(
            text,
            None,
            add_special_tokens=True,
            max_length=self.max_length,
            padding='max_length',
            truncation=True,
            return_token_type_ids=True,
            return_attention_mask=True,
            return_tensors='pt'
        )
        item = {
            'input_ids': inputs['input_ids'].flatten(),
            'attention_mask': inputs['attention_mask'].flatten(),
            'token_type_ids': inputs['token_type_ids'].flatten(),
        }

        if self.targets is not None:
            item['targets'] = torch.tensor(self.targets[index], dtype=torch.float)

        return item

# Model Architecture
class EmotionClassifier(nn.Module):
    def __init__(self, n_classes=11, dropout_rate=0.2):
        super(EmotionClassifier, self).__init__()
        self.roberta = RobertaModel.from_pretrained('roberta-base')
        self.drop = nn.Dropout(p=dropout_rate)
        self.out = nn.Linear(self.roberta.config.hidden_size, n_classes)

    def forward(self, input_ids, attention_mask, token_type_ids):
        outputs = self.roberta(
            input_ids=input_ids,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids
        )

        # Get the [CLS] token representation
        pooled_output = outputs.pooler_output
        output = self.drop(pooled_output)
        return self.out(output)

# Fixed function to calculate F1 score during training
def calculate_f1_score(y_true, y_pred):
    """
    Calculate macro F1 score for multi-label classification

    Args:
        y_true: numpy array of true labels
        y_pred: numpy array of predicted labels (after thresholding)

    Returns:
        macro_f1: macro-averaged F1 score
    """
    # Make sure inputs are numpy arrays
    if isinstance(y_true, torch.Tensor):
        y_true = y_true.cpu().numpy()
    if isinstance(y_pred, torch.Tensor):
        y_pred = y_pred.cpu().numpy()

    # Calculate F1 score for each class
    f1_scores = []
    for i in range(y_true.shape[1]):
        # Skip classes with no positive examples in this batch
        if np.sum(y_true[:, i]) > 0:
            class_f1 = f1_score(y_true[:, i], y_pred[:, i], zero_division=0)
            f1_scores.append(class_f1)
    # Return 0 if no valid classes
    if len(f1_scores) == 0:
        return 0.0

    # Calculate macro F1 score
    return np.mean(f1_scores)

# Updated training function with wandb integration
def train_model(model, train_loader, val_loader, epochs=15, lr=2e-5, model_save_path='best_roberta_model.pt'):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}")

    model.to(device)

    # Binary Cross Entropy with Logits Loss for multi-label classification
    criterion = nn.BCEWithLogitsLoss()

    # Optimizer with weight decay
    optimizer = AdamW(model.parameters(), lr=lr, weight_decay=1e-4)

    # Learning rate scheduler
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='max', factor=0.5, patience=1, verbose=True
    )

    best_f1 = 0
    history = {'train_loss': [], 'val_loss': [], 'val_f1': []}

    for epoch in range(epochs):
        print(f"\nEpoch {epoch+1}/{epochs}")

        # Training phase
        model.train()
        train_loss = 0
        all_train_preds = []
        all_train_targets = []

        for batch in train_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            token_type_ids = batch['token_type_ids'].to(device)
            targets = batch['targets'].to(device)

            optimizer.zero_grad()

            outputs = model(input_ids, attention_mask, token_type_ids)
            loss = criterion(outputs, targets)

            loss.backward()
            optimizer.step()

            train_loss += loss.item()

            # Store predictions and targets for F1 calculation
            preds = torch.sigmoid(outputs) > 0.5
            all_train_preds.append(preds.cpu().detach().numpy())
            all_train_targets.append(targets.cpu().numpy())

        train_loss = train_loss / len(train_loader)
        history['train_loss'].append(train_loss)
        # Calculate training F1 score
        all_train_preds = np.vstack(all_train_preds)
        all_train_targets = np.vstack(all_train_targets)
        train_f1 = calculate_f1_score(all_train_targets, all_train_preds)

        # Validation phase
        model.eval()
        val_loss = 0
        all_val_preds = []
        all_val_targets = []

        with torch.no_grad():
            for batch in val_loader:
                input_ids = batch['input_ids'].to(device)
                attention_mask = batch['attention_mask'].to(device)
                token_type_ids = batch['token_type_ids'].to(device)
                targets = batch['targets'].to(device)

                outputs = model(input_ids, attention_mask, token_type_ids)
                loss = criterion(outputs, targets)

                val_loss += loss.item()

                # Apply sigmoid and threshold to get binary predictions
                preds = torch.sigmoid(outputs) > 0.5
                all_val_preds.append(preds.cpu().detach().numpy())
                all_val_targets.append(targets.cpu().numpy())

        val_loss = val_loss / len(val_loader)
        history['val_loss'].append(val_loss)

        # Concatenate predictions and targets
        all_val_preds = np.vstack(all_val_preds)
        all_val_targets = np.vstack(all_val_targets)

        # Calculate macro F1 score
        val_f1 = calculate_f1_score(all_val_targets, all_val_preds)
        history['val_f1'].append(val_f1)

        print(f"Train Loss: {train_loss:.4f}, Train F1: {train_f1:.4f}, Val Loss: {val_loss:.4f}, Val F1: {val_f1:.4f}")

        # Update learning rate based on F1 score
        scheduler.step(val_f1)

        # Log to wandb
        wandb.log({
            "epoch": epoch + 1,
            "train_loss": train_loss,
            "train_f1": train_f1,
            "val_loss": val_loss,
            "val_f1": val_f1,
            "learning_rate": optimizer.param_groups[0]['lr']
        })

        # Save the best model
        if val_f1 > best_f1:
            best_f1 = val_f1
            torch.save(model.state_dict(), model_save_path)
            print(f"New best model saved with F1: {best_f1:.4f}")

            # Log best model to wandb
            wandb.run.summary["best_val_f1"] = best_f1
            wandb.run.summary["best_model_epoch"] = epoch + 1

    return history, best_f1

# Evaluation function with wandb logging
def evaluate_model(model, test_loader, emotion_cols):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)
    model.eval()

    all_preds = []
    all_targets = []

    with torch.no_grad():
        for batch in test_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            token_type_ids = batch['token_type_ids'].to(device)

            outputs = model(input_ids, attention_mask, token_type_ids)

            # Apply sigmoid to get probabilities and threshold
            preds = (torch.sigmoid(outputs) > 0.5).cpu().detach().numpy()
            all_preds.append(preds)

            if 'targets' in batch:
                targets = batch['targets'].cpu().numpy()
                all_targets.append(targets)

    all_preds = np.vstack(all_preds)
    # If we have targets (for validation), calculate metrics
    if all_targets:
        all_targets = np.vstack(all_targets)

        # Calculate precision, recall, and F1 for each emotion
        results = {}
        f1_scores = []
        emotion_metrics = {}

        for i, emotion in enumerate(emotion_cols):
            # Skip emotions with no positive examples
            if np.sum(all_targets[:, i]) > 0:
                precision = precision_score(all_targets[:, i], all_preds[:, i], zero_division=0)
                recall = recall_score(all_targets[:, i], all_preds[:, i], zero_division=0)
                f1 = f1_score(all_targets[:, i], all_preds[:, i], zero_division=0)

                results[emotion] = {
                    'precision': precision,
                    'recall': recall,
                    'f1': f1
                }

                # Add to metrics for wandb logging
                emotion_metrics[f"{emotion}_precision"] = precision
                emotion_metrics[f"{emotion}_recall"] = recall
                emotion_metrics[f"{emotion}_f1"] = f1

                f1_scores.append(f1)

        # Calculate macro-average F1 score
        macro_f1 = np.mean(f1_scores)
        print(f"Macro-average F1 Score: {macro_f1:.4f}")

        # Log all emotion metrics to wandb at once
        emotion_metrics["macro_f1"] = macro_f1
        wandb.log(emotion_metrics)

        # Print detailed results for each emotion
        for emotion, metrics in results.items():
            print(f"{emotion}: Precision={metrics['precision']:.4f}, Recall={metrics['recall']:.4f}, F1={metrics['f1']:.4f}")

        return all_preds, macro_f1, results

    return all_preds

# Main experiment function with wandb integration
def run_experiment():
    # Define file paths with clear print statements for debugging
    train_path = '/content/drive/MyDrive/train.csv'
    test_path = '/content/drive/MyDrive/test.csv'
    model_save_path = '/content/drive/MyDrive/best_roberta_model.pt'
    predictions_path = '/content/drive/MyDrive/roberta_predictions.csv'

    print(f"Training data path: {train_path}")
    print(f"Testing data path: {test_path}")
    print(f"Model save path: {model_save_path}")
    print(f"Predictions save path: {predictions_path}")

    # Check if files exist
    print(f"Training file exists: {os.path.exists(train_path)}")
    print(f"Testing file exists: {os.path.exists(test_path)}")

    # Initialize wandb run with project name and configuration
    wandb.init(
        project="emotion-classification",
        config={
            "model_type": "roberta-base",
            "max_length": 128,
            "batch_size": 16,
            "learning_rate": 2e-5,
            "epochs": 15,
            "dropout_rate": 0.3,
            "optimizer": "AdamW",
            "scheduler": "ReduceLROnPlateau"
        }
    )

    # Load datasets
    print(f"Loading training data from {train_path}")
    train_df = pd.read_csv(train_path)
    print(f"Loading testing data from {test_path}")
    test_df = pd.read_csv(test_path)

    # Print dataset info
    print(f"Training dataset shape: {train_df.shape}")
    print(f"Testing dataset shape: {test_df.shape}")

    # Define emotion columns
    emotion_cols = ['anger', 'anticipation', 'disgust', 'fear', 'joy', 'love',
                   'optimism', 'pessimism', 'sadness', 'surprise', 'trust']

    # Check if emotion columns exist in the dataframes
    for col in emotion_cols:
        if col not in train_df.columns:
            print(f"Warning: {col} not found in training data")

    # Check for 'NONE' values in test data before conversion
    print("Checking for 'NONE' values in test data:")
    for col in emotion_cols:
        if col in test_df.columns:
            unique_vals = test_df[col].unique()
            if 'NONE' in unique_vals:
                print(f"Column {col} contains 'NONE' values")

    # Handle 'NONE' values and convert emotion columns to numeric - improved method
    for col in emotion_cols:
        if col in train_df.columns:
            # Replace 'NONE' with NaN first (case-insensitive)
            train_df[col] = train_df[col].replace(['NONE', 'None', 'none'], np.nan)
            # Then convert to float using to_numeric with coercion
            train_df[col] = pd.to_numeric(train_df[col], errors='coerce').fillna(0).astype(np.float32)

        if col in test_df.columns:
            # Replace 'NONE' with NaN first (case-insensitive)
            test_df[col] = test_df[col].replace(['NONE', 'None', 'none'], np.nan)
            # Then convert to float using to_numeric with coercion
            test_df[col] = pd.to_numeric(test_df[col], errors='coerce').fillna(0).astype(np.float32)

    # Check class distribution
    print("Emotion distribution in training set:")
    emotions_dist = train_df[emotion_cols].sum().sort_values(ascending=False)
    print(emotions_dist)

    # Log class distribution to wandb
    for emotion in emotion_cols:
        wandb.run.summary[f"{emotion}_count"] = float(train_df[emotion].sum())

    # Initialize tokenizer
    tokenizer = RobertaTokenizer.from_pretrained('roberta-base')

    # Create datasets
    train_dataset = EmotionDataset(train_df, tokenizer)
    test_dataset = EmotionDataset(test_df, tokenizer)

    # Split training data into train and validation sets (90/10 split)
    train_size = int(0.9 * len(train_dataset))
    val_size = len(train_dataset) - train_size
    # Use a fixed generator for reproducibility
    generator = torch.Generator().manual_seed(42)
    train_subset, val_subset = torch.utils.data.random_split(
        train_dataset, [train_size, val_size], generator=generator
    )

    # Create data loaders with a smaller batch size if needed
    batch_size = 16
    train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_subset, batch_size=batch_size)
    test_loader = DataLoader(test_dataset, batch_size=batch_size)

    # Calculate class weights for handling imbalance
    class_weights = []
    total_samples = len(train_df)

    for col in emotion_cols:
        pos_samples = train_df[col].sum()
        # Avoid division by zero
        if pos_samples == 0:
            class_weights.append(1.0)
        else:
            # More weight to minority class
            class_weights.append(total_samples / (2 * pos_samples))
    class_weights = torch.tensor(class_weights, dtype=torch.float)
    print("Class weights:", class_weights)

    # Log class weights to wandb
    for i, emotion in enumerate(emotion_cols):
        wandb.run.summary[f"{emotion}_weight"] = class_weights[i].item()

    # Initialize model with a slightly higher dropout for regularization
    model = EmotionClassifier(n_classes=len(emotion_cols), dropout_rate=0.3)

    # Watch the model with wandb to track gradients and parameters
    wandb.watch(model, log="all")

    # Train model
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    class_weights = class_weights.to(device)
    criterion = nn.BCEWithLogitsLoss(pos_weight=class_weights)

    # Train model
    history, best_f1 = train_model(model, train_loader, val_loader, epochs=15, lr=2e-5, model_save_path=model_save_path)

    # Log best model to wandb
    wandb.log({"best_f1": best_f1})

    # Load best model
    print(f"Loading best model from {model_save_path}")
    model.load_state_dict(torch.load(model_save_path))

    # Evaluate on test set
    if all(col in test_df.columns for col in emotion_cols):
        predictions, macro_f1, detailed_results = evaluate_model(model, test_loader, emotion_cols)

        # Plot F1 scores for each emotion
        emotions = list(detailed_results.keys())
        f1_scores = [detailed_results[emotion]['f1'] for emotion in emotions]

        plt.figure(figsize=(12, 6))
        sns.barplot(x=emotions, y=f1_scores)
        plt.title('F1 Score by Emotion')
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.savefig('/content/drive/MyDrive/emotion_f1_scores.png')
        plt.show()

        # Log the plot to wandb
        wandb.log({"f1_score_by_emotion": wandb.Image('/content/drive/MyDrive/emotion_f1_scores.png')})
    else:
        # If test set doesn't have labels, just make predictions
        print("Test set doesn't have emotion labels, making predictions...")
        predictions = evaluate_model(model, test_loader, emotion_cols)

    # Create submission dataframe with ID and Tweet
    print("Creating prediction dataframe...")
    submission_df = test_df[['ID', 'Tweet']].copy()
    for i, emotion in enumerate(emotion_cols):
        submission_df[emotion] = predictions[:, i]

    # Save predictions to multiple locations for redundancy
    try:
        # 1. Save to Google Drive
        print(f"Saving predictions to {predictions_path}...")
        submission_df.to_csv(predictions_path, index=False)
        print(f"Predictions successfully saved to {predictions_path}")

        # 2. Save to local Colab storage
        local_path = '/content/roberta_predictions.csv'
        submission_df.to_csv(local_path, index=False)
        print(f"Predictions saved to local Colab storage: {local_path}")

        # 3. Save to a new folder in Drive for better organization
        output_dir = '/content/drive/MyDrive/colab_outputs'
        os.makedirs(output_dir, exist_ok=True)
        output_path = f"{output_dir}/roberta_predictions.csv"
        submission_df.to_csv(output_path, index=False)
        print(f"Predictions saved to organized folder: {output_path}")

        # Verify files were created
        for path in [predictions_path, local_path, output_path]:
            if os.path.exists(path):
                print(f"✓ File exists at {path}")
                print(f" File size: {os.path.getsize(path)} bytes")
            else:
                print(f"✗ File does not exist at {path}")

        # 4. Download the file directly to your local machine
        from google.colab import files
        files.download(local_path)
        print("File download initiated. Check your browser's download folder.")

    except Exception as e:
        print(f"Error saving predictions: {str(e)}")

        # Try saving to Colab local storage as backup
        try:
            local_path = '/content/roberta_predictions.csv'
            submission_df.to_csv(local_path, index=False)
            print(f"Predictions saved to local Colab storage: {local_path}")

            # Download the file directly to your local machine
            from google.colab import files
            files.download(local_path)
            print("File download initiated. Check your browser's download folder.")
        except Exception as download_error:
            print(f"Error downloading file: {str(download_error)}")
            print("Please try downloading manually using the file browser.")

    # Plot training history
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history['train_loss'], label='Train Loss')
    plt.plot(history['val_loss'], label='Validation Loss')
    plt.title('Loss over epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history['val_f1'], label='Validation F1')
    plt.title('F1 Score over epochs')
    plt.xlabel('Epoch')
    plt.ylabel('F1 Score')
    plt.legend()

    plt.tight_layout()
    plt.savefig('/content/drive/MyDrive/training_plots.png')
    plt.show()

    # Log the plot to wandb
    wandb.log({"training_plots": wandb.Image('/content/drive/MyDrive/training_plots.png')})

    print("Training plots saved to Google Drive")

    # Also download the training plots
    try:
        files.download('/content/drive/MyDrive/training_plots.png')
        print("Training plots download initiated.")
    except Exception as e:
        print(f"Error downloading training plots: {str(e)}")

    # Finish the wandb run
    wandb.finish()

if __name__ == "__main__":
    run_experiment()
# Out:
# Mounted at /content/drive
# Google Drive mounted at /content/drive
# Files in Google Drive root:
#  - Untitled document (17).gdoc
#  - Untitled document (16).gdoc
#  - Untitled document (15).gdoc
#  - To-do list (1).gsheet
#  - Prediction.gsheet
#  - Copy of Middle class.gsheet
#  - PD Exercise.gsheet
#  - Untitled spreadsheet (4).gsheet
#  - Untitled document (14).gdoc
#  - Untitled document (13).gdoc
#  - Ritin_Wadekar_LAB#7.gsheet
#  - Untitled document (12).gdoc
#  - Untitled document (11).gdoc
#  - Ritin_Wadekar_LAB#8_text.gdoc
#  - Untitled spreadsheet (3).gsheet
#  - To-do list.gsheet
#  - Copy of TOEFL Live : 03rd Oct'22 08.30pm.gsheet
#  - Ritin_Wadekar_LAB#9.gdoc
#  - Cover Letter Vertiv.gdoc
#  - Step 1 Group 6.gdoc
#  - Untitled document (10).gdoc
#  - Cover Letter  Student Union - Student Life Programs.gdoc
#  - Ritesh Uncle Payments.gsheet
#  - Untitled document (9).gdoc
#  - Cover Letter Communications Student Assistant.gdoc
#  - Untitled document (8).gdoc
#  - Advanced Statistics HW4.gdoc
#  - Final year project summary.gdoc
#  - Application for Internships.gsheet
#  - Cover Letter Express Analytics.gdoc
#  - STV Inc Details.gdoc
#  - Untitled spreadsheet (2).gsheet
#  - Nihon Kohden America Cover Letter.gdoc
#  - meta-2024-Apr-13-15-38-55
#  - meta-2024-Apr-13-15-47-07
#  - Expenses in USD.gsheet
#  - Untitled document (7).gdoc
#  - Colab Notebooks
#  - Untitled spreadsheet (1).gsheet
#  - Untitled spreadsheet.gsheet
#  - AML Certificate Essay.gdoc
#  - Model Selection Baseball.gdoc
#  - MP&F Cover Letter.gdoc
#  - Cover Letter CRA.gdoc
#  - Discussion Points.gdoc
#  - Schedule(25th Sept - 10th Oct).gdoc
#  - Untitled document (6).gdoc
#  - Cover Letter Eastman.gdoc
#  - Untitled document (5).gdoc
#  - Cold Email.gsheet
#  - Ritin: Data Analyst Intern.gdoc
#  - Untitled presentation.gslides
#  - Plan of Action - 8th Dec to 20th Jan.gdoc
#  - Letter: No Income Source.gdoc
#  - Untitled document (4).gdoc
#  - Untitled map.gmap
#  - Google Earth
#  - Untitled document (3).gdoc
#  - Referral Email.gdoc
#  - Untitled document (2).gdoc
#  - Fraud.gdoc
#  - Fraud.gsheet
#  - Internship Assignment.gdoc
#  - HR Questions.gdoc
#  - Final Cleaned Dataset.ipynb
#  - Outlier Detection.ipynb
#  - Outliers.ipynb
#  - Apple Referral.gdoc
#  - Plan.gdoc
#  - Cold Emails.gsheet
#  - nda_extraction_small.csv
#  - Applied LLMs HW1
#  - Report_AppliedLLM_HW1.gdoc
#  - Applications.gdoc
#  - test.csv
#  - train.csv
#  - Untitled document (1).gdoc
#  - Ritin Wadekar Resume.pdf
#  - Untitled document.gdoc
#  - Part 3.gdoc
#  - train_sample_5_percent.csv
#  - test_sample_5_percent.csv
#  - colab_outputs
#  - roberta_predictions.csv
#  - colab_downloads
#  - roberta_predictions(2).csv
#  - emotion_f1_scores_distilbert.png
#  - training_plots_distilbert.png
#  - distilbert_predictions.csv
#  - best_albert_model.pt
#  - training_plots.png
#  - emotion_f1_scores.png
#  - albert_predictions.csv
#  - best_roberta_model.pt
# Error setting up API keys: Secret 9b6d1aa4302021a3f18a2a55bf5fafca0061a5b3 does not exist.
# Continuing without proper authentication...
# Training data path: /content/drive/MyDrive/train.csv
# Testing data path: /content/drive/MyDrive/test.csv
# Model save path: /content/drive/MyDrive/best_roberta_model.pt
# Predictions save path: /content/drive/MyDrive/roberta_predictions.csv
# Training file exists: True
# Testing file exists: True
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: ritinwadekar6 (ritinwadekar6-onpoint-insights) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/content/wandb/run-20250425_003249-j41a5rwx</code>
# Syncing run <strong><a href='https://wandb.ai/ritinwadekar6-onpoint-insights/emotion-classification/runs/j41a5rwx' target="_blank">light-yogurt-1</a></strong> to <a href='https://wandb.ai/ritinwadekar6-onpoint-insights/emotion-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ritinwadekar6-onpoint-insights/emotion-classification' target="_blank">https://wandb.ai/ritinwadekar6-onpoint-insights/emotion-classification</a>
#  View run at <a href='https://wandb.ai/ritinwadekar6-onpoint-insights/emotion-classification/runs/j41a5rwx' target="_blank">https://wandb.ai/ritinwadekar6-onpoint-insights/emotion-classification/runs/j41a5rwx</a>
# Loading training data from /content/drive/MyDrive/train.csv
# Loading testing data from /content/drive/MyDrive/test.csv
# Training dataset shape: (7724, 13)
# Testing dataset shape: (3259, 13)
# Checking for 'NONE' values in test data:
# Column anger contains 'NONE' values
# Column anticipation contains 'NONE' values
# Column disgust contains 'NONE' values
# Column fear contains 'NONE' values
# Column joy contains 'NONE' values
# Column love contains 'NONE' values
# Column optimism contains 'NONE' values
# Column pessimism contains 'NONE' values
# Column sadness contains 'NONE' values
# Column surprise contains 'NONE' values
# Column trust contains 'NONE' values
# Emotion distribution in training set:
# disgust         2921.0
# joy             2877.0
# anger           2859.0
# optimism        2291.0
# sadness         2273.0
# fear            1363.0
# anticipation    1102.0
# pessimism        895.0
# love             832.0
# trust            400.0
# surprise         396.0
# dtype: float32
# <ipython-input-1-7d890d770018>:408: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test_df[col] = test_df[col].replace(['NONE', 'None', 'none'], np.nan)
# <ipython-input-1-7d890d770018>:408: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test_df[col] = test_df[col].replace(['NONE', 'None', 'none'], np.nan)
# <ipython-input-1-7d890d770018>:408: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test_df[col] = test_df[col].replace(['NONE', 'None', 'none'], np.nan)
# <ipython-input-1-7d890d770018>:408: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test_df[col] = test_df[col].replace(['NONE', 'None', 'none'], np.nan)
# <ipython-input-1-7d890d770018>:408: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test_df[col] = test_df[col].replace(['NONE', 'None', 'none'], np.nan)
# <ipython-input-1-7d890d770018>:408: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test_df[col] = test_df[col].replace(['NONE', 'None', 'none'], np.nan)
# <ipython-input-1-7d890d770018>:408: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test_df[col] = test_df[col].replace(['NONE', 'None', 'none'], np.nan)
# <ipython-input-1-7d890d770018>:408: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test_df[col] = test_df[col].replace(['NONE', 'None', 'none'], np.nan)
# <ipython-input-1-7d890d770018>:408: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test_df[col] = test_df[col].replace(['NONE', 'None', 'none'], np.nan)
# <ipython-input-1-7d890d770018>:408: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test_df[col] = test_df[col].replace(['NONE', 'None', 'none'], np.nan)
# <ipython-input-1-7d890d770018>:408: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test_df[col] = test_df[col].replace(['NONE', 'None', 'none'], np.nan)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Class weights: tensor([1.3508, 3.5045, 1.3221, 2.8335, 1.3424, 4.6418, 1.6857, 4.3151, 1.6991,
#         9.7525, 9.6550])
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using device: cuda
#
# Epoch 1/15
# Train Loss: 0.3800, Train F1: 0.3402, Val Loss: 0.3195, Val F1: 0.4710
# New best model saved with F1: 0.4710
#
# Epoch 2/15
# Train Loss: 0.2954, Train F1: 0.4882, Val Loss: 0.2952, Val F1: 0.5433
# New best model saved with F1: 0.5433
#
# Epoch 3/15
# Train Loss: 0.2611, Train F1: 0.5716, Val Loss: 0.2924, Val F1: 0.5512
# New best model saved with F1: 0.5512
#
# Epoch 4/15
# Train Loss: 0.2343, Train F1: 0.6092, Val Loss: 0.3041, Val F1: 0.5670
# New best model saved with F1: 0.5670
#
# Epoch 5/15
# Train Loss: 0.2108, Train F1: 0.6602, Val Loss: 0.3057, Val F1: 0.5569
#
# Epoch 6/15
# Train Loss: 0.1881, Train F1: 0.7132, Val Loss: 0.3172, Val F1: 0.5651
#
# Epoch 7/15
# Train Loss: 0.1573, Train F1: 0.7636, Val Loss: 0.3269, Val F1: 0.5750
# New best model saved with F1: 0.5750
#
# Epoch 8/15
# Train Loss: 0.1411, Train F1: 0.7949, Val Loss: 0.3435, Val F1: 0.5903
# New best model saved with F1: 0.5903
#
# Epoch 9/15
# Train Loss: 0.1265, Train F1: 0.8219, Val Loss: 0.3414, Val F1: 0.5758
#
# Epoch 10/15
# Train Loss: 0.1132, Train F1: 0.8450, Val Loss: 0.3640, Val F1: 0.5828
#
# Epoch 11/15
# Train Loss: 0.0968, Train F1: 0.8800, Val Loss: 0.3713, Val F1: 0.5751
#
# Epoch 12/15
# Train Loss: 0.0892, Train F1: 0.8881, Val Loss: 0.3766, Val F1: 0.5732
#
# Epoch 13/15
# Train Loss: 0.0812, Train F1: 0.9055, Val Loss: 0.3841, Val F1: 0.5832
#
# Epoch 14/15
# Train Loss: 0.0766, Train F1: 0.9131, Val Loss: 0.3894, Val F1: 0.5734
#
# Epoch 15/15
# Train Loss: 0.0725, Train F1: 0.9196, Val Loss: 0.3921, Val F1: 0.5869
# Loading best model from /content/drive/MyDrive/best_roberta_model.pt
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:3596: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:138: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Macro-average F1 Score: nan
# Creating prediction dataframe...
# Saving predictions to /content/drive/MyDrive/roberta_predictions.csv...
# Predictions successfully saved to /content/drive/MyDrive/roberta_predictions.csv
# Predictions saved to local Colab storage: /content/roberta_predictions.csv
# Predictions saved to organized folder: /content/drive/MyDrive/colab_outputs/roberta_predictions.csv
# ✓ File exists at /content/drive/MyDrive/roberta_predictions.csv
#  File size: 559919 bytes
# ✓ File exists at /content/roberta_predictions.csv
#  File size: 559919 bytes
# ✓ File exists at /content/drive/MyDrive/colab_outputs/roberta_predictions.csv
#  File size: 559919 bytes
# File download initiated. Check your browser's download folder.
# Training plots saved to Google Drive
# Training plots download initiated.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_f1</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>learning_rate</td><td>█████▄▄▄▄▂▂▁▁▁▁</td></tr><tr><td>train_f1</td><td>▁▃▄▄▅▆▆▆▇▇█████</td></tr><tr><td>train_loss</td><td>█▆▅▅▄▄▃▃▂▂▂▁▁▁▁</td></tr><tr><td>val_f1</td><td>▁▅▆▇▆▇▇█▇█▇▇█▇█</td></tr><tr><td>val_loss</td><td>▃▁▁▂▂▃▃▅▄▆▇▇▇██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>anger_count</td><td>2859</td></tr><tr><td>anger_weight</td><td>1.35082</td></tr><tr><td>anticipation_count</td><td>1102</td></tr><tr><td>anticipation_weight</td><td>3.50454</td></tr><tr><td>best_f1</td><td>0.59032</td></tr><tr><td>best_model_epoch</td><td>8</td></tr><tr><td>best_val_f1</td><td>0.59032</td></tr><tr><td>disgust_count</td><td>2921</td></tr><tr><td>disgust_weight</td><td>1.32215</td></tr><tr><td>epoch</td><td>15</td></tr><tr><td>fear_count</td><td>1363</td></tr><tr><td>fear_weight</td><td>2.83346</td></tr><tr><td>joy_count</td><td>2877</td></tr><tr><td>joy_weight</td><td>1.34237</td></tr><tr><td>learning_rate</td><td>0.0</td></tr><tr><td>love_count</td><td>832</td></tr><tr><td>love_weight</td><td>4.64183</td></tr><tr><td>macro_f1</td><td>nan</td></tr><tr><td>optimism_count</td><td>2291</td></tr><tr><td>optimism_weight</td><td>1.68573</td></tr><tr><td>pessimism_count</td><td>895</td></tr><tr><td>pessimism_weight</td><td>4.31508</td></tr><tr><td>sadness_count</td><td>2273</td></tr><tr><td>sadness_weight</td><td>1.69908</td></tr><tr><td>surprise_count</td><td>396</td></tr><tr><td>surprise_weight</td><td>9.75253</td></tr><tr><td>train_f1</td><td>0.91961</td></tr><tr><td>train_loss</td><td>0.0725</td></tr><tr><td>trust_count</td><td>400</td></tr><tr><td>trust_weight</td><td>9.655</td></tr><tr><td>val_f1</td><td>0.58689</td></tr><tr><td>val_loss</td><td>0.39209</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">light-yogurt-1</strong> at: <a href='https://wandb.ai/ritinwadekar6-onpoint-insights/emotion-classification/runs/j41a5rwx' target="_blank">https://wandb.ai/ritinwadekar6-onpoint-insights/emotion-classification/runs/j41a5rwx</a><br> View project at: <a href='https://wandb.ai/ritinwadekar6-onpoint-insights/emotion-classification' target="_blank">https://wandb.ai/ritinwadekar6-onpoint-insights/emotion-classification</a><br>Synced 5 W&B file(s), 2 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250425_003249-j41a5rwx/logs</code>
